# %%
import pandas as pd
import numpy as np
from citipy import citipy
import requests 
import time
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 759

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + g_key

# %%
#city_weather = requests.get(city_url).json()
#city_weather

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]['description']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | dikson
# Processing Record 3 of Set 1 | punta arenas
# Processing Record 4 of Set 1 | ambilobe
# Processing Record 5 of Set 1 | rikitea
# Processing Record 6 of Set 1 | nome
# Processing Record 7 of Set 1 | lebu
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | banda aceh
# Processing Record 10 of Set 1 | ushuaia
# Processing Record 11 of Set 1 | comodoro rivadavia
# Processing Record 12 of Set 1 | la ronge
# Processing Record 13 of Set 1 | mohpa
# Processing Record 14 of Set 1 | hithadhoo
# Processing Record 15 of Set 1 | luau
# Processing Record 16 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 1 | christchurch
# Processing Record 18 of Set 1 | saskylakh
# Processing Record 19 of Set 1 | busselton
# Processing Record 20 of Set 1 | bredasdorp
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | barbar
# City not found. Skipping...
# Processing Record 23 of Set 1 | diyarb najm
# Processing Record 24 of Set 1 | hami
# Processing Record 25 of Set 1 | sarangani
# Processing Record 26 of Set 1 | padilla
# Processing Record 27 of Set 1 | laishevo
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | ust-koksa
# Processing Record 30 of Set 1 | vao
# Processing Record 31 of Set 1 | hobart
# Processing Record 32 of Set 1 | airai
# Processing Record 33 of Set 1 | mataura
# Processing Record 34 of Set 1 | huarmey
# Processing Record 35 of Set 1 | burgeo
# Processing Record 36 of Set 1 | rehlingen-siersburg
# Processing Record 37 of Set 1 | komsomolskiy
# Processing Record 38 of Set 1 | miranda
# Processing Record 39 of Set 1 | coihaique
# Processing Record 40 of Set 1 | flin flon
# Processing Record 41 of Set 1 | asau
# Processing Record 42 of Set 1 | altay
# Processing Record 43 of Set 1 | coquimbo
# Processing Record 44 of Set 1 | roald
# Processing Record 45 of Set 1 | yellowknife
# Processing Record 46 of Set 1 | atlantic city
# Processing Record 47 of Set 1 | kodiak
# Processing Record 48 of Set 1 | sao joao da barra
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | port lincoln
# Processing Record 1 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 2 of Set 2 | arraial do cabo
# Processing Record 3 of Set 2 | tosya
# Processing Record 4 of Set 2 | wairoa
# Processing Record 5 of Set 2 | ternate
# Processing Record 6 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 2 | kruisfontein
# Processing Record 8 of Set 2 | nantucket
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | north bend
# Processing Record 11 of Set 2 | chapais
# Processing Record 12 of Set 2 | riverton
# Processing Record 13 of Set 2 | sitka
# Processing Record 14 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 15 of Set 2 | aranos
# Processing Record 16 of Set 2 | lake havasu city
# Processing Record 17 of Set 2 | provideniya
# Processing Record 18 of Set 2 | mecca
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | lodja
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | srednekolymsk
# Processing Record 23 of Set 2 | treinta y tres
# Processing Record 24 of Set 2 | impfondo
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | mareeba
# Processing Record 27 of Set 2 | alyangula
# Processing Record 28 of Set 2 | yahotyn
# Processing Record 29 of Set 2 | puerto ayora
# Processing Record 30 of Set 2 | araouane
# Processing Record 31 of Set 2 | zhangye
# Processing Record 32 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 2 | kailasahar
# City not found. Skipping...
# Processing Record 34 of Set 2 | tuy hoa
# Processing Record 35 of Set 2 | yeppoon
# Processing Record 36 of Set 2 | aybak
# City not found. Skipping...
# Processing Record 37 of Set 2 | atuona
# Processing Record 38 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 39 of Set 2 | east london
# Processing Record 40 of Set 2 | longyearbyen
# Processing Record 41 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 42 of Set 2 | geraldton
# Processing Record 43 of Set 2 | barrow
# Processing Record 44 of Set 2 | bograd
# Processing Record 45 of Set 2 | karasjok
# Processing Record 46 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 47 of Set 2 | henties bay
# Processing Record 48 of Set 2 | noumea
# Processing Record 49 of Set 2 | gualaceo
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | vaini
# Processing Record 2 of Set 3 | corinto
# Processing Record 3 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 3 | hof
# Processing Record 5 of Set 3 | nanortalik
# Processing Record 6 of Set 3 | clyde river
# Processing Record 7 of Set 3 | freeport
# Processing Record 8 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 3 | souillac
# Processing Record 10 of Set 3 | hengshui
# Processing Record 11 of Set 3 | bluff
# Processing Record 12 of Set 3 | natal
# Processing Record 13 of Set 3 | avarua
# Processing Record 14 of Set 3 | salalah
# Processing Record 15 of Set 3 | tiarei
# Processing Record 16 of Set 3 | torbay
# Processing Record 17 of Set 3 | cayenne
# Processing Record 18 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 19 of Set 3 | ponta do sol
# Processing Record 20 of Set 3 | tuatapere
# Processing Record 21 of Set 3 | claudio
# Processing Record 22 of Set 3 | kaa-khem
# Processing Record 23 of Set 3 | klaksvik
# Processing Record 24 of Set 3 | hilo
# Processing Record 25 of Set 3 | farsund
# Processing Record 26 of Set 3 | severo-kurilsk
# Processing Record 27 of Set 3 | ulladulla
# Processing Record 28 of Set 3 | port blair
# Processing Record 29 of Set 3 | shimoda
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | bengkulu
# Processing Record 32 of Set 3 | mehamn
# Processing Record 33 of Set 3 | sheboygan
# Processing Record 34 of Set 3 | turinskaya sloboda
# Processing Record 35 of Set 3 | grindavik
# Processing Record 36 of Set 3 | pontianak
# Processing Record 37 of Set 3 | hofn
# Processing Record 38 of Set 3 | isangel
# Processing Record 39 of Set 3 | bethel
# Processing Record 40 of Set 3 | taoudenni
# Processing Record 41 of Set 3 | tasiilaq
# Processing Record 42 of Set 3 | honiara
# Processing Record 43 of Set 3 | banjarmasin
# Processing Record 44 of Set 3 | narsaq
# Processing Record 45 of Set 3 | shache
# Processing Record 46 of Set 3 | talnakh
# Processing Record 47 of Set 3 | cape town
# Processing Record 48 of Set 3 | mazamitla
# Processing Record 49 of Set 3 | nyurba
# Processing Record 50 of Set 3 | meulaboh
# Processing Record 1 of Set 4 | ishimbay
# Processing Record 2 of Set 4 | faya
# Processing Record 3 of Set 4 | amurzet
# Processing Record 4 of Set 4 | ostrovnoy
# Processing Record 5 of Set 4 | palmer
# Processing Record 6 of Set 4 | oriximina
# Processing Record 7 of Set 4 | jaciara
# Processing Record 8 of Set 4 | muros
# Processing Record 9 of Set 4 | marcona
# City not found. Skipping...
# Processing Record 10 of Set 4 | carauari
# Processing Record 11 of Set 4 | prabumulih
# Processing Record 12 of Set 4 | pisco
# Processing Record 13 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 14 of Set 4 | tuktoyaktuk
# Processing Record 15 of Set 4 | okhotsk
# Processing Record 16 of Set 4 | nikolskoye
# Processing Record 17 of Set 4 | thompson
# Processing Record 18 of Set 4 | hasaki
# Processing Record 19 of Set 4 | rosetta
# Processing Record 20 of Set 4 | menomonie
# Processing Record 21 of Set 4 | merauke
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | cap malheureux
# Processing Record 24 of Set 4 | zheleznodorozhnyy
# Processing Record 25 of Set 4 | santa isabel
# Processing Record 26 of Set 4 | maragogi
# Processing Record 27 of Set 4 | basmat
# Processing Record 28 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | miramar
# Processing Record 31 of Set 4 | vung tau
# Processing Record 32 of Set 4 | houma
# Processing Record 33 of Set 4 | lavrentiya
# Processing Record 34 of Set 4 | high prairie
# Processing Record 35 of Set 4 | turkistan
# Processing Record 36 of Set 4 | deputatskiy
# Processing Record 37 of Set 4 | mount isa
# Processing Record 38 of Set 4 | muroto
# Processing Record 39 of Set 4 | saint anthony
# Processing Record 40 of Set 4 | kawalu
# Processing Record 41 of Set 4 | sabzevar
# Processing Record 42 of Set 4 | georgetown
# Processing Record 43 of Set 4 | mazyr
# Processing Record 44 of Set 4 | grants pass
# Processing Record 45 of Set 4 | mount gambier
# Processing Record 46 of Set 4 | nishihara
# Processing Record 47 of Set 4 | hanyang
# Processing Record 48 of Set 4 | paamiut
# Processing Record 49 of Set 4 | xining
# Processing Record 50 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 1 of Set 5 | misratah
# Processing Record 2 of Set 5 | wuwei
# Processing Record 3 of Set 5 | khatanga
# Processing Record 4 of Set 5 | kuzovatovo
# Processing Record 5 of Set 5 | cisternino
# Processing Record 6 of Set 5 | soyo
# Processing Record 7 of Set 5 | ilinskoye-khovanskoye
# Processing Record 8 of Set 5 | opuwo
# Processing Record 9 of Set 5 | codrington
# Processing Record 10 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 11 of Set 5 | pevek
# Processing Record 12 of Set 5 | beroroha
# Processing Record 13 of Set 5 | bilma
# Processing Record 14 of Set 5 | xam nua
# Processing Record 15 of Set 5 | udayagiri
# Processing Record 16 of Set 5 | shitanjing
# Processing Record 17 of Set 5 | cravo norte
# Processing Record 18 of Set 5 | gushikawa
# Processing Record 19 of Set 5 | buala
# Processing Record 20 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 21 of Set 5 | maniitsoq
# Processing Record 22 of Set 5 | novonikolayevskiy
# Processing Record 23 of Set 5 | kasongo-lunda
# Processing Record 24 of Set 5 | sao filipe
# Processing Record 25 of Set 5 | mogadishu
# Processing Record 26 of Set 5 | la ligua
# Processing Record 27 of Set 5 | inzer
# Processing Record 28 of Set 5 | angarsk
# Processing Record 29 of Set 5 | margate
# Processing Record 30 of Set 5 | leshukonskoye
# Processing Record 31 of Set 5 | cherskiy
# Processing Record 32 of Set 5 | kavaratti
# Processing Record 33 of Set 5 | kabo
# Processing Record 34 of Set 5 | qaanaaq
# Processing Record 35 of Set 5 | port-gentil
# Processing Record 36 of Set 5 | saint-philippe
# Processing Record 37 of Set 5 | biak
# Processing Record 38 of Set 5 | ebolowa
# Processing Record 39 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 5 | beringovskiy
# Processing Record 41 of Set 5 | millau
# Processing Record 42 of Set 5 | tilichiki
# Processing Record 43 of Set 5 | enterprise
# Processing Record 44 of Set 5 | chapada dos guimaraes
# Processing Record 45 of Set 5 | itoman
# Processing Record 46 of Set 5 | cartagena
# Processing Record 47 of Set 5 | samarai
# Processing Record 48 of Set 5 | soe
# Processing Record 49 of Set 5 | kangaatsiaq
# Processing Record 50 of Set 5 | chernigovka
# Processing Record 1 of Set 6 | kaduna
# Processing Record 2 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 6 | durgapur
# Processing Record 4 of Set 6 | lakes entrance
# Processing Record 5 of Set 6 | manado
# Processing Record 6 of Set 6 | guangyuan
# Processing Record 7 of Set 6 | upernavik
# Processing Record 8 of Set 6 | cidreira
# Processing Record 9 of Set 6 | arlit
# Processing Record 10 of Set 6 | timizart
# Processing Record 11 of Set 6 | haines junction
# Processing Record 12 of Set 6 | lengshuitan
# Processing Record 13 of Set 6 | vila franca do campo
# Processing Record 14 of Set 6 | maxixe
# Processing Record 15 of Set 6 | carutapera
# Processing Record 16 of Set 6 | puerto leguizamo
# Processing Record 17 of Set 6 | peniche
# Processing Record 18 of Set 6 | new norfolk
# Processing Record 19 of Set 6 | katsuura
# Processing Record 20 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 6 | aksarka
# Processing Record 22 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | pozo colorado
# Processing Record 24 of Set 6 | richards bay
# Processing Record 25 of Set 6 | bamako
# Processing Record 26 of Set 6 | antofagasta
# Processing Record 27 of Set 6 | siena
# Processing Record 28 of Set 6 | batemans bay
# Processing Record 29 of Set 6 | hibbing
# Processing Record 30 of Set 6 | wanning
# Processing Record 31 of Set 6 | chancay
# Processing Record 32 of Set 6 | barabinsk
# Processing Record 33 of Set 6 | laguna
# Processing Record 34 of Set 6 | ancud
# Processing Record 35 of Set 6 | esperance
# Processing Record 36 of Set 6 | korem
# Processing Record 37 of Set 6 | chuy
# Processing Record 38 of Set 6 | san andres
# Processing Record 39 of Set 6 | twin falls
# Processing Record 40 of Set 6 | los barrios
# Processing Record 41 of Set 6 | san patricio
# Processing Record 42 of Set 6 | luganville
# Processing Record 43 of Set 6 | monrovia
# Processing Record 44 of Set 6 | namatanai
# Processing Record 45 of Set 6 | doha
# Processing Record 46 of Set 6 | marseille
# Processing Record 47 of Set 6 | huilong
# Processing Record 48 of Set 6 | inhambane
# Processing Record 49 of Set 6 | san-pedro
# Processing Record 50 of Set 6 | conde
# Processing Record 1 of Set 7 | kenai
# Processing Record 2 of Set 7 | luderitz
# Processing Record 3 of Set 7 | santander
# Processing Record 4 of Set 7 | karratha
# Processing Record 5 of Set 7 | victoria
# Processing Record 6 of Set 7 | ilulissat
# Processing Record 7 of Set 7 | kaseda
# Processing Record 8 of Set 7 | dingle
# Processing Record 9 of Set 7 | hamilton
# Processing Record 10 of Set 7 | cockburn town
# Processing Record 11 of Set 7 | nuuk
# Processing Record 12 of Set 7 | ipixuna
# Processing Record 13 of Set 7 | castro
# Processing Record 14 of Set 7 | elizabeth city
# Processing Record 15 of Set 7 | armizonskoye
# Processing Record 16 of Set 7 | rafaela
# Processing Record 17 of Set 7 | vardo
# Processing Record 18 of Set 7 | fortuna
# Processing Record 19 of Set 7 | fare
# Processing Record 20 of Set 7 | bilibino
# Processing Record 21 of Set 7 | bolivar
# Processing Record 22 of Set 7 | oktyabrskiy
# Processing Record 23 of Set 7 | camacha
# Processing Record 24 of Set 7 | ondjiva
# Processing Record 25 of Set 7 | kollumerland
# City not found. Skipping...
# Processing Record 26 of Set 7 | aden
# Processing Record 27 of Set 7 | caravelas
# Processing Record 28 of Set 7 | acapulco
# Processing Record 29 of Set 7 | vanderhoof
# Processing Record 30 of Set 7 | mangrol
# Processing Record 31 of Set 7 | palaiokhora
# City not found. Skipping...
# Processing Record 32 of Set 7 | sao borja
# Processing Record 33 of Set 7 | guerrero negro
# Processing Record 34 of Set 7 | peleduy
# Processing Record 35 of Set 7 | mahadday weyne
# City not found. Skipping...
# Processing Record 36 of Set 7 | saldanha
# Processing Record 37 of Set 7 | ardakan
# Processing Record 38 of Set 7 | port hardy
# Processing Record 39 of Set 7 | marfino
# Processing Record 40 of Set 7 | astana
# Processing Record 41 of Set 7 | coahuayana
# Processing Record 42 of Set 7 | temaraia
# City not found. Skipping...
# Processing Record 43 of Set 7 | iqaluit
# Processing Record 44 of Set 7 | kardla
# Processing Record 45 of Set 7 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 7 | moundsville
# Processing Record 47 of Set 7 | makakilo city
# Processing Record 48 of Set 7 | bafoulabe
# Processing Record 49 of Set 7 | warwick
# Processing Record 50 of Set 7 | arroyo grande
# Processing Record 1 of Set 8 | presidencia roque saenz pena
# Processing Record 2 of Set 8 | dunedin
# Processing Record 3 of Set 8 | zhanakorgan
# Processing Record 4 of Set 8 | tabou
# Processing Record 5 of Set 8 | northam
# Processing Record 6 of Set 8 | verkhnevilyuysk
# Processing Record 7 of Set 8 | lompoc
# Processing Record 8 of Set 8 | san isidro
# Processing Record 9 of Set 8 | lata
# Processing Record 10 of Set 8 | livramento
# Processing Record 11 of Set 8 | vieques
# Processing Record 12 of Set 8 | atar
# Processing Record 13 of Set 8 | naze
# Processing Record 14 of Set 8 | aklavik
# Processing Record 15 of Set 8 | saint george
# Processing Record 16 of Set 8 | kerrabe
# City not found. Skipping...
# Processing Record 17 of Set 8 | kiruna
# Processing Record 18 of Set 8 | leningradskiy
# Processing Record 19 of Set 8 | te anau
# Processing Record 20 of Set 8 | liverpool
# Processing Record 21 of Set 8 | catamarca
# Processing Record 22 of Set 8 | pangnirtung
# Processing Record 23 of Set 8 | lasa
# Processing Record 24 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 25 of Set 8 | alofi
# Processing Record 26 of Set 8 | zaraza
# Processing Record 27 of Set 8 | trat
# Processing Record 28 of Set 8 | dicabisagan
# Processing Record 29 of Set 8 | balkhash
# Processing Record 30 of Set 8 | kaitangata
# Processing Record 31 of Set 8 | savannakhet
# Processing Record 32 of Set 8 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 8 | muisne
# Processing Record 34 of Set 8 | kununurra
# Processing Record 35 of Set 8 | gondanglegi
# Processing Record 36 of Set 8 | rio grande
# Processing Record 37 of Set 8 | yerbogachen
# Processing Record 38 of Set 8 | garmsar
# Processing Record 39 of Set 8 | xuanhua
# Processing Record 40 of Set 8 | krutinka
# Processing Record 41 of Set 8 | la romana
# Processing Record 42 of Set 8 | veraval
# Processing Record 43 of Set 8 | kavieng
# Processing Record 44 of Set 8 | manzanillo
# Processing Record 45 of Set 8 | cabo san lucas
# Processing Record 46 of Set 8 | inirida
# Processing Record 47 of Set 8 | san pietro vernotico
# Processing Record 48 of Set 8 | satitoa
# City not found. Skipping...
# Processing Record 49 of Set 8 | bridgeton
# Processing Record 50 of Set 8 | sekoma
# Processing Record 1 of Set 9 | ulaangom
# Processing Record 2 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 3 of Set 9 | cedar city
# Processing Record 4 of Set 9 | san lazaro
# Processing Record 5 of Set 9 | valdez
# Processing Record 6 of Set 9 | warrnambool
# Processing Record 7 of Set 9 | xai-xai
# Processing Record 8 of Set 9 | lahat
# Processing Record 9 of Set 9 | guane
# Processing Record 10 of Set 9 | storsteinnes
# Processing Record 11 of Set 9 | bukama
# Processing Record 12 of Set 9 | quatre cocos
# Processing Record 13 of Set 9 | necochea
# Processing Record 14 of Set 9 | ciudad bolivar
# Processing Record 15 of Set 9 | jalu
# Processing Record 16 of Set 9 | namibe
# Processing Record 17 of Set 9 | yukhnov
# Processing Record 18 of Set 9 | fairbanks
# Processing Record 19 of Set 9 | blankenberge
# Processing Record 20 of Set 9 | shubarkuduk
# Processing Record 21 of Set 9 | nemuro
# Processing Record 22 of Set 9 | tagum
# Processing Record 23 of Set 9 | marawi
# Processing Record 24 of Set 9 | verkhoyansk
# Processing Record 25 of Set 9 | kuntaur
# Processing Record 26 of Set 9 | kangaba
# Processing Record 27 of Set 9 | sistranda
# Processing Record 28 of Set 9 | gboko
# Processing Record 29 of Set 9 | terrace
# Processing Record 30 of Set 9 | tulcingo
# City not found. Skipping...
# Processing Record 31 of Set 9 | vanavara
# Processing Record 32 of Set 9 | benemerito de las americas
# Processing Record 33 of Set 9 | sagarejo
# Processing Record 34 of Set 9 | balabac
# Processing Record 35 of Set 9 | itaberai
# Processing Record 36 of Set 9 | vallenar
# Processing Record 37 of Set 9 | lashio
# Processing Record 38 of Set 9 | muravlenko
# Processing Record 39 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 40 of Set 9 | itaituba
# Processing Record 41 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 9 | prykolotne
# Processing Record 43 of Set 9 | mersing
# Processing Record 44 of Set 9 | porto novo
# Processing Record 45 of Set 9 | chimoio
# Processing Record 46 of Set 9 | waddan
# Processing Record 47 of Set 9 | ginda
# Processing Record 48 of Set 9 | grand-santi
# Processing Record 49 of Set 9 | inverell
# Processing Record 50 of Set 9 | jos
# Processing Record 1 of Set 10 | qujing
# Processing Record 2 of Set 10 | sabang
# Processing Record 3 of Set 10 | hobbs
# Processing Record 4 of Set 10 | broome
# Processing Record 5 of Set 10 | port augusta
# Processing Record 6 of Set 10 | sorland
# Processing Record 7 of Set 10 | cao bang
# Processing Record 8 of Set 10 | axim
# Processing Record 9 of Set 10 | ouadda
# Processing Record 10 of Set 10 | kamenka
# Processing Record 11 of Set 10 | bondo
# Processing Record 12 of Set 10 | syracuse
# Processing Record 13 of Set 10 | rawson
# Processing Record 14 of Set 10 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 10 | virginia beach
# Processing Record 16 of Set 10 | saint-prosper
# Processing Record 17 of Set 10 | walvis bay
# Processing Record 18 of Set 10 | tessalit
# Processing Record 19 of Set 10 | canavieiras
# Processing Record 20 of Set 10 | shrigonda
# Processing Record 21 of Set 10 | taltal
# Processing Record 22 of Set 10 | aktau
# Processing Record 23 of Set 10 | panalingaan
# Processing Record 24 of Set 10 | katherine
# Processing Record 25 of Set 10 | pendleton
# Processing Record 26 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 10 | flinders
# Processing Record 28 of Set 10 | iranshahr
# Processing Record 29 of Set 10 | omboue
# Processing Record 30 of Set 10 | forestville
# Processing Record 31 of Set 10 | celestun
# Processing Record 32 of Set 10 | cap-aux-meules
# Processing Record 33 of Set 10 | lingao
# Processing Record 34 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 35 of Set 10 | hastings
# Processing Record 36 of Set 10 | chardara
# Processing Record 37 of Set 10 | abu samrah
# Processing Record 38 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 39 of Set 10 | atambua
# Processing Record 40 of Set 10 | khovu-aksy
# Processing Record 41 of Set 10 | portland
# Processing Record 42 of Set 10 | beyneu
# Processing Record 43 of Set 10 | novyy urgal
# Processing Record 44 of Set 10 | coro
# Processing Record 45 of Set 10 | tambul
# City not found. Skipping...
# Processing Record 46 of Set 10 | vestmannaeyjar
# Processing Record 47 of Set 10 | progreso
# Processing Record 48 of Set 10 | andenes
# Processing Record 49 of Set 10 | beaverlodge
# Processing Record 50 of Set 10 | gryazovets
# Processing Record 1 of Set 11 | tutoia
# Processing Record 2 of Set 11 | varhaug
# Processing Record 3 of Set 11 | ust-kuyga
# Processing Record 4 of Set 11 | kachiry
# Processing Record 5 of Set 11 | mergui
# City not found. Skipping...
# Processing Record 6 of Set 11 | dossor
# Processing Record 7 of Set 11 | lorengau
# Processing Record 8 of Set 11 | kodinsk
# Processing Record 9 of Set 11 | port hedland
# Processing Record 10 of Set 11 | saint-michel-des-saints
# Processing Record 11 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 11 | ishigaki
# Processing Record 13 of Set 11 | koscian
# Processing Record 14 of Set 11 | farmington
# Processing Record 15 of Set 11 | watertown
# Processing Record 16 of Set 11 | kahului
# Processing Record 17 of Set 11 | mayo
# Processing Record 18 of Set 11 | daru
# Processing Record 19 of Set 11 | houston
# Processing Record 20 of Set 11 | svetlogorsk
# Processing Record 21 of Set 11 | basco
# Processing Record 22 of Set 11 | harlingen
# Processing Record 23 of Set 11 | talara
# Processing Record 24 of Set 11 | kijang
# Processing Record 25 of Set 11 | teya
# Processing Record 26 of Set 11 | tiksi
# Processing Record 27 of Set 11 | takhtamygda
# Processing Record 28 of Set 11 | uarini
# Processing Record 29 of Set 11 | xacmaz
# Processing Record 30 of Set 11 | rauma
# Processing Record 31 of Set 11 | buluang
# Processing Record 32 of Set 11 | labuan
# Processing Record 33 of Set 11 | shingu
# Processing Record 34 of Set 11 | imperia
# Processing Record 35 of Set 11 | lagoa
# Processing Record 36 of Set 11 | saint-denis
# Processing Record 37 of Set 11 | yumen
# Processing Record 38 of Set 11 | catia la mar
# Processing Record 39 of Set 11 | ahuimanu
# Processing Record 40 of Set 11 | labrea
# Processing Record 41 of Set 11 | karaul
# City not found. Skipping...
# Processing Record 42 of Set 11 | tazovskiy
# Processing Record 43 of Set 11 | faanui
# Processing Record 44 of Set 11 | norman wells
# Processing Record 45 of Set 11 | tsihombe
# City not found. Skipping...
# Processing Record 46 of Set 11 | fukue
# Processing Record 47 of Set 11 | partizanskoye
# Processing Record 48 of Set 11 | ayr
# Processing Record 49 of Set 11 | lianzhou
# Processing Record 50 of Set 11 | los llanos de aridane
# Processing Record 1 of Set 12 | olafsvik
# Processing Record 2 of Set 12 | obihiro
# Processing Record 3 of Set 12 | nalut
# Processing Record 4 of Set 12 | amargosa
# Processing Record 5 of Set 12 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 12 | kamina
# Processing Record 7 of Set 12 | waipawa
# Processing Record 8 of Set 12 | toba tek singh
# Processing Record 9 of Set 12 | lundazi
# Processing Record 10 of Set 12 | wewak
# Processing Record 11 of Set 12 | raton
# Processing Record 12 of Set 12 | north platte
# Processing Record 13 of Set 12 | swan hill
# Processing Record 14 of Set 12 | mayachnyy
# Processing Record 15 of Set 12 | itarema
# Processing Record 16 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 17 of Set 12 | alta floresta
# Processing Record 18 of Set 12 | vila velha
# Processing Record 19 of Set 12 | copiapo
# Processing Record 20 of Set 12 | cairns
# Processing Record 21 of Set 12 | sayat
# Processing Record 22 of Set 12 | katobu
# Processing Record 23 of Set 12 | heyang
# Processing Record 24 of Set 12 | vaitape
# Processing Record 25 of Set 12 | mana
# Processing Record 26 of Set 12 | port macquarie
# Processing Record 27 of Set 12 | pyu
# Processing Record 28 of Set 12 | harper
# Processing Record 29 of Set 12 | tallahassee
# Processing Record 30 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 31 of Set 12 | tres arroyos
# Processing Record 32 of Set 12 | kharhial
# Processing Record 33 of Set 12 | baboua
# City not found. Skipping...
# Processing Record 34 of Set 12 | baoding
# Processing Record 35 of Set 12 | kigoma
# Processing Record 36 of Set 12 | khilok
# Processing Record 37 of Set 12 | apache junction
# Processing Record 38 of Set 12 | lewiston
# Processing Record 39 of Set 12 | grand centre
# City not found. Skipping...
# Processing Record 40 of Set 12 | poso
# Processing Record 41 of Set 12 | luanda
# Processing Record 42 of Set 12 | punta alta
# Processing Record 43 of Set 12 | yaan
# Processing Record 44 of Set 12 | tevriz
# Processing Record 45 of Set 12 | san cristobal
# Processing Record 46 of Set 12 | santa maria
# Processing Record 47 of Set 12 | goderich
# Processing Record 48 of Set 12 | kingman
# Processing Record 49 of Set 12 | hirara
# Processing Record 50 of Set 12 | blackwater
# Processing Record 1 of Set 13 | tuzha
# Processing Record 2 of Set 13 | gull lake
# Processing Record 3 of Set 13 | segovia
# Processing Record 4 of Set 13 | khandyga
# Processing Record 5 of Set 13 | ust-nera
# Processing Record 6 of Set 13 | roma
# Processing Record 7 of Set 13 | helong
# Processing Record 8 of Set 13 | ken caryl
# Processing Record 9 of Set 13 | dhone
# Processing Record 10 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 11 of Set 13 | drexel heights
# Processing Record 12 of Set 13 | malkapur
# Processing Record 13 of Set 13 | zhigansk
# Processing Record 14 of Set 13 | am timan
# Processing Record 15 of Set 13 | san vicente
# Processing Record 16 of Set 13 | okakarara
# Processing Record 17 of Set 13 | chorozinho
# Processing Record 18 of Set 13 | trincomalee
# Processing Record 19 of Set 13 | el campo
# Processing Record 20 of Set 13 | nikolsk
# Processing Record 21 of Set 13 | ketchikan
# Processing Record 22 of Set 13 | guarapari
# Processing Record 23 of Set 13 | puerto del rosario
# Processing Record 24 of Set 13 | weligama
# Processing Record 25 of Set 13 | djibo
# Processing Record 26 of Set 13 | gunnedah
# Processing Record 27 of Set 13 | tevaitoa
# Processing Record 28 of Set 13 | tabiauea
# City not found. Skipping...
# Processing Record 29 of Set 13 | kailua
# Processing Record 30 of Set 13 | umm lajj
# Processing Record 31 of Set 13 | rocha
# Processing Record 32 of Set 13 | sterling
# Processing Record 33 of Set 13 | newport
# Processing Record 34 of Set 13 | ivanivka
# Processing Record 35 of Set 13 | kyabe
# Processing Record 36 of Set 13 | wattegama
# Processing Record 37 of Set 13 | krasnoselkup
# Processing Record 38 of Set 13 | beloha
# Processing Record 39 of Set 13 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 13 | berlevag
# Processing Record 41 of Set 13 | otradinskiy
# City not found. Skipping...
# Processing Record 42 of Set 13 | shulan
# Processing Record 43 of Set 13 | poum
# Processing Record 44 of Set 13 | aginskoye
# Processing Record 45 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 46 of Set 13 | kapuskasing
# Processing Record 47 of Set 13 | maceio
# Processing Record 48 of Set 13 | tinskoy
# Processing Record 49 of Set 13 | arvika
# Processing Record 50 of Set 13 | sao miguel do araguaia
# Processing Record 1 of Set 14 | dongsheng
# Processing Record 2 of Set 14 | yulara
# Processing Record 3 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 14 | acarau
# Processing Record 5 of Set 14 | quibdo
# Processing Record 6 of Set 14 | dharchula
# Processing Record 7 of Set 14 | kiama
# Processing Record 8 of Set 14 | bakel
# Processing Record 9 of Set 14 | sakhnovshchyna
# Processing Record 10 of Set 14 | likhoslavl
# Processing Record 11 of Set 14 | gritsovskiy
# Processing Record 12 of Set 14 | marsh harbour
# Processing Record 13 of Set 14 | piripiri
# Processing Record 14 of Set 14 | ankazoabo
# Processing Record 15 of Set 14 | umm kaddadah
# Processing Record 16 of Set 14 | takoradi
# Processing Record 17 of Set 14 | chukhloma
# Processing Record 18 of Set 14 | atikokan
# Processing Record 19 of Set 14 | tetouan
# Processing Record 20 of Set 14 | dostpur
# Processing Record 21 of Set 14 | ushtobe
# Processing Record 22 of Set 14 | alto araguaia
# Processing Record 23 of Set 14 | milledgeville
# Processing Record 24 of Set 14 | bogorodsk
# Processing Record 25 of Set 14 | boras
# Processing Record 26 of Set 14 | prince rupert
# Processing Record 27 of Set 14 | blackfoot
# Processing Record 28 of Set 14 | buraydah
# Processing Record 29 of Set 14 | kita
# Processing Record 30 of Set 14 | iracoubo
# Processing Record 31 of Set 14 | kilindoni
# Processing Record 32 of Set 14 | hope
# Processing Record 33 of Set 14 | deniliquin
# Processing Record 34 of Set 14 | mwinilunga
# Processing Record 35 of Set 14 | balikpapan
# Processing Record 36 of Set 14 | mountain home
# Processing Record 37 of Set 14 | poronaysk
# Processing Record 38 of Set 14 | erzin
# Processing Record 39 of Set 14 | yalchiki
# City not found. Skipping...
# Processing Record 40 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 41 of Set 14 | moree
# Processing Record 42 of Set 14 | havelock
# Processing Record 43 of Set 14 | rabaul
# Processing Record 44 of Set 14 | kem
# Processing Record 45 of Set 14 | iralaya
# Processing Record 46 of Set 14 | mocambique
# City not found. Skipping...
# Processing Record 47 of Set 14 | goulburn
# Processing Record 48 of Set 14 | dauphin
# Processing Record 49 of Set 14 | itaueira
# Processing Record 50 of Set 14 | plettenberg bay
# Processing Record 1 of Set 15 | dutlwe
# Processing Record 2 of Set 15 | kirkuk
# Processing Record 3 of Set 15 | puerto colombia
# Processing Record 4 of Set 15 | lodwar
# Processing Record 5 of Set 15 | kapustin yar-1
# City not found. Skipping...
# Processing Record 6 of Set 15 | ankazobe
# Processing Record 7 of Set 15 | tyup
# Processing Record 8 of Set 15 | chumphon
# Processing Record 9 of Set 15 | puerto baquerizo moreno
# Processing Record 10 of Set 15 | kolyvan
# Processing Record 11 of Set 15 | ransang
# Processing Record 12 of Set 15 | vanimo
# Processing Record 13 of Set 15 | serowe
# Processing Record 14 of Set 15 | boa vista
# Processing Record 15 of Set 15 | yar-sale
# Processing Record 16 of Set 15 | dakar
# Processing Record 17 of Set 15 | sirjan
# Processing Record 18 of Set 15 | riyadh
# Processing Record 19 of Set 15 | okahandja
# Processing Record 20 of Set 15 | betare oya
# Processing Record 21 of Set 15 | bozeman
# Processing Record 22 of Set 15 | boralday
# Processing Record 23 of Set 15 | outjo
# Processing Record 24 of Set 15 | inuvik
# Processing Record 25 of Set 15 | megion
# Processing Record 26 of Set 15 | imbituba
# Processing Record 27 of Set 15 | russell
# Processing Record 28 of Set 15 | thinadhoo
# Processing Record 29 of Set 15 | borovskoy
# Processing Record 30 of Set 15 | dong hoi
# Processing Record 31 of Set 15 | yarmouth
# Processing Record 32 of Set 15 | puerto carreno
# Processing Record 33 of Set 15 | vestmanna
# Processing Record 34 of Set 15 | nalvo
# Processing Record 35 of Set 15 | lafiagi
# Processing Record 36 of Set 15 | aleysk
# Processing Record 37 of Set 15 | ugoofaaru
# Processing Record 38 of Set 15 | moose factory
# Processing Record 39 of Set 15 | kadoma
# Processing Record 40 of Set 15 | picton
# Processing Record 41 of Set 15 | papara
# Processing Record 42 of Set 15 | alice springs
# Processing Record 43 of Set 15 | strezhevoy
# Processing Record 44 of Set 15 | balingasay
# Processing Record 45 of Set 15 | seoul
# Processing Record 46 of Set 15 | barra do garcas
# Processing Record 47 of Set 15 | lewistown
# Processing Record 48 of Set 15 | aykhal
# Processing Record 49 of Set 15 | altenstadt
# Processing Record 50 of Set 15 | grand gaube
# Processing Record 1 of Set 16 | kidal
# Processing Record 2 of Set 16 | santa luzia
# Processing Record 3 of Set 16 | eskasem
# City not found. Skipping...
# Processing Record 4 of Set 16 | mount darwin
# Processing Record 5 of Set 16 | owando
# Processing Record 6 of Set 16 | hambantota
# Processing Record 7 of Set 16 | loknya
# Processing Record 8 of Set 16 | uvat
# Processing Record 9 of Set 16 | iquique
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
weatherpy_db = pd.DataFrame(city_data)
weatherpy_db.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus -34.4187   19.2345     61.90        77          89
# 1        Dikson  73.5069   80.5464    -22.02        95          69
# 2  Punta Arenas -53.1500  -70.9167     50.11        66          75
# 3      Ambilobe -13.2000   49.0500     72.90        77          76
# 4       Rikitea -23.1203 -134.9692     76.73        73          43
# 5          Nome  64.5011 -165.4064      8.67        78          90
# 6          Lebu -37.6167  -73.6500     52.70        89           7
# 7    Chokurdakh  70.6333  147.9167    -27.22        96         100
# 8    Banda Aceh   5.5577   95.3222     78.08        82         100
# 9       Ushuaia -54.8000  -68.3000     53.26        47          20
#
#    Wind Speed Country Current Description
# 0       12.93      ZA     overcast clouds
# 1       11.59      RU       broken clouds
# 2       20.71      CL       broken clouds
# 3        3.38      MG       broken clouds
# 4       15.35      PF    scattered clouds
# 5       21.85      US                snow
# 6       19.93      CL           clear sky
# 7        9.95      RU     overcast clouds
# 8       10.33      ID     overcast clouds
# 9       23.02      AR          few clouds

# %%
new_order = ['City','Country', 'Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
weatherpy_db = weatherpy_db[new_order]

# %%
weatherpy_db.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Hermanus      ZA -34.4187   19.2345     61.90        77          89
# 1        Dikson      RU  73.5069   80.5464    -22.02        95          69
# 2  Punta Arenas      CL -53.1500  -70.9167     50.11        66          75
# 3      Ambilobe      MG -13.2000   49.0500     72.90        77          76
# 4       Rikitea      PF -23.1203 -134.9692     76.73        73          43
# 5          Nome      US  64.5011 -165.4064      8.67        78          90
# 6          Lebu      CL -37.6167  -73.6500     52.70        89           7
# 7    Chokurdakh      RU  70.6333  147.9167    -27.22        96         100
# 8    Banda Aceh      ID   5.5577   95.3222     78.08        82         100
# 9       Ushuaia      AR -54.8000  -68.3000     53.26        47          20
#
#    Wind Speed Current Description
# 0       12.93     overcast clouds
# 1       11.59       broken clouds
# 2       20.71       broken clouds
# 3        3.38       broken clouds
# 4       15.35    scattered clouds
# 5       21.85                snow
# 6       19.93           clear sky
# 7        9.95     overcast clouds
# 8       10.33     overcast clouds
# 9       23.02          few clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weatherpy_db.to_csv(output_data_file, index_label="City_ID")
