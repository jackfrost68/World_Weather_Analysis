# %%
import pandas as pd
import numpy as np
from citipy import citipy
import requests 
import time
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 765

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + g_key

# %%
#city_weather = requests.get(city_url).json()
#city_weather

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_description = city_weather["weather"][0]['description']
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                         "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mbale
# Processing Record 2 of Set 1 | pringsewu
# Processing Record 3 of Set 1 | lydenburg
# Processing Record 4 of Set 1 | rampur
# Processing Record 5 of Set 1 | avera
# Processing Record 6 of Set 1 | port elizabeth
# Processing Record 7 of Set 1 | raton
# Processing Record 8 of Set 1 | port alfred
# Processing Record 9 of Set 1 | vardo
# Processing Record 10 of Set 1 | banda aceh
# Processing Record 11 of Set 1 | ambulu
# Processing Record 12 of Set 1 | sitka
# Processing Record 13 of Set 1 | seoul
# Processing Record 14 of Set 1 | bluff
# Processing Record 15 of Set 1 | ushuaia
# Processing Record 16 of Set 1 | rikitea
# Processing Record 17 of Set 1 | verkhnevilyuysk
# Processing Record 18 of Set 1 | chifeng
# Processing Record 19 of Set 1 | sao filipe
# Processing Record 20 of Set 1 | katsuura
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | sompeta
# Processing Record 23 of Set 1 | chuy
# Processing Record 24 of Set 1 | hermanus
# Processing Record 25 of Set 1 | puerto ayora
# Processing Record 26 of Set 1 | mataura
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | asau
# Processing Record 30 of Set 1 | victoria
# Processing Record 31 of Set 1 | mar del plata
# Processing Record 32 of Set 1 | tuktoyaktuk
# Processing Record 33 of Set 1 | vaini
# Processing Record 34 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 35 of Set 1 | lebu
# Processing Record 36 of Set 1 | batemans bay
# Processing Record 37 of Set 1 | lerwick
# Processing Record 38 of Set 1 | east london
# Processing Record 39 of Set 1 | isangel
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | arraial do cabo
# Processing Record 42 of Set 1 | atuona
# Processing Record 43 of Set 1 | villarrica
# Processing Record 44 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 45 of Set 1 | tawkar
# City not found. Skipping...
# Processing Record 46 of Set 1 | harrisonburg
# Processing Record 47 of Set 1 | sakakah
# Processing Record 48 of Set 1 | miramar
# Processing Record 49 of Set 1 | new norfolk
# Processing Record 50 of Set 1 | xadani
# City not found. Skipping...
# Processing Record 1 of Set 2 | port lincoln
# Processing Record 2 of Set 2 | hilo
# Processing Record 3 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 2 | saravan
# Processing Record 5 of Set 2 | butaritari
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | san luis
# Processing Record 8 of Set 2 | strezhevoy
# Processing Record 9 of Set 2 | ribeira grande
# Processing Record 10 of Set 2 | san vicente
# Processing Record 11 of Set 2 | kruisfontein
# Processing Record 12 of Set 2 | normandin
# Processing Record 13 of Set 2 | kegayli
# City not found. Skipping...
# Processing Record 14 of Set 2 | camacha
# Processing Record 15 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 2 | constitucion
# Processing Record 17 of Set 2 | castro
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | kapaa
# Processing Record 20 of Set 2 | saint-augustin
# Processing Record 21 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 2 | torbay
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | kautokeino
# Processing Record 25 of Set 2 | lata
# Processing Record 26 of Set 2 | bredasdorp
# Processing Record 27 of Set 2 | aflu
# City not found. Skipping...
# Processing Record 28 of Set 2 | adra
# Processing Record 29 of Set 2 | hithadhoo
# Processing Record 30 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 31 of Set 2 | georgetown
# Processing Record 32 of Set 2 | genhe
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | san quintin
# Processing Record 35 of Set 2 | sisimiut
# Processing Record 36 of Set 2 | bambous virieux
# Processing Record 37 of Set 2 | bargal
# City not found. Skipping...
# Processing Record 38 of Set 2 | kushiro
# Processing Record 39 of Set 2 | yulara
# Processing Record 40 of Set 2 | khatanga
# Processing Record 41 of Set 2 | tyukalinsk
# Processing Record 42 of Set 2 | kavaratti
# Processing Record 43 of Set 2 | ponta do sol
# Processing Record 44 of Set 2 | marrakesh
# Processing Record 45 of Set 2 | bethel
# Processing Record 46 of Set 2 | deputatskiy
# Processing Record 47 of Set 2 | kihei
# Processing Record 48 of Set 2 | longyearbyen
# Processing Record 49 of Set 2 | sao felix do xingu
# Processing Record 50 of Set 2 | egvekinot
# Processing Record 1 of Set 3 | prince rupert
# Processing Record 2 of Set 3 | inverbervie
# Processing Record 3 of Set 3 | cape town
# Processing Record 4 of Set 3 | barrow
# Processing Record 5 of Set 3 | ponta delgada
# Processing Record 6 of Set 3 | sainte-maxime
# Processing Record 7 of Set 3 | martapura
# Processing Record 8 of Set 3 | alpena
# Processing Record 9 of Set 3 | asmara
# Processing Record 10 of Set 3 | souillac
# Processing Record 11 of Set 3 | woodstock
# Processing Record 12 of Set 3 | mahebourg
# Processing Record 13 of Set 3 | mitsamiouli
# Processing Record 14 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 3 | ichihara
# Processing Record 16 of Set 3 | marystown
# Processing Record 17 of Set 3 | hovd
# Processing Record 18 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 19 of Set 3 | pokhara
# Processing Record 20 of Set 3 | luderitz
# Processing Record 21 of Set 3 | kaitangata
# Processing Record 22 of Set 3 | ilulissat
# Processing Record 23 of Set 3 | urbano santos
# Processing Record 24 of Set 3 | general roca
# Processing Record 25 of Set 3 | carballo
# Processing Record 26 of Set 3 | tasiilaq
# Processing Record 27 of Set 3 | san joaquin
# Processing Record 28 of Set 3 | sena madureira
# Processing Record 29 of Set 3 | noumea
# Processing Record 30 of Set 3 | saint anthony
# Processing Record 31 of Set 3 | taltal
# Processing Record 32 of Set 3 | sioux lookout
# Processing Record 33 of Set 3 | besuki
# Processing Record 34 of Set 3 | kudahuvadhoo
# Processing Record 35 of Set 3 | ikwiriri
# Processing Record 36 of Set 3 | amahai
# Processing Record 37 of Set 3 | lakes entrance
# Processing Record 38 of Set 3 | pemba
# Processing Record 39 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 3 | chokurdakh
# Processing Record 41 of Set 3 | andrelandia
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | krasnozatonskiy
# Processing Record 44 of Set 3 | ardmore
# Processing Record 45 of Set 3 | yellowknife
# Processing Record 46 of Set 3 | aksarka
# Processing Record 47 of Set 3 | zhigansk
# Processing Record 48 of Set 3 | bonavista
# Processing Record 49 of Set 3 | gornozavodsk
# Processing Record 50 of Set 3 | thompson
# Processing Record 1 of Set 4 | ouesso
# Processing Record 2 of Set 4 | saint george
# Processing Record 3 of Set 4 | kodiak
# Processing Record 4 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 4 | mount pleasant
# Processing Record 6 of Set 4 | villa nueva
# Processing Record 7 of Set 4 | sobolevo
# Processing Record 8 of Set 4 | cabo san lucas
# Processing Record 9 of Set 4 | carnarvon
# Processing Record 10 of Set 4 | hauterive
# Processing Record 11 of Set 4 | avarua
# Processing Record 12 of Set 4 | abha
# Processing Record 13 of Set 4 | leningradskiy
# Processing Record 14 of Set 4 | kutahya
# Processing Record 15 of Set 4 | beringovskiy
# Processing Record 16 of Set 4 | angoche
# Processing Record 17 of Set 4 | kayseri
# Processing Record 18 of Set 4 | hun
# Processing Record 19 of Set 4 | radomsko
# Processing Record 20 of Set 4 | el grullo
# Processing Record 21 of Set 4 | ghanzi
# Processing Record 22 of Set 4 | talavera de la reina
# Processing Record 23 of Set 4 | geraldton
# Processing Record 24 of Set 4 | namibe
# Processing Record 25 of Set 4 | yar-sale
# Processing Record 26 of Set 4 | cururupu
# Processing Record 27 of Set 4 | puerto quijarro
# Processing Record 28 of Set 4 | broken hill
# Processing Record 29 of Set 4 | hambantota
# Processing Record 30 of Set 4 | tiksi
# Processing Record 31 of Set 4 | nalut
# Processing Record 32 of Set 4 | berzasca
# Processing Record 33 of Set 4 | klyuchi
# Processing Record 34 of Set 4 | saldanha
# Processing Record 35 of Set 4 | naze
# Processing Record 36 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 4 | gao
# Processing Record 38 of Set 4 | shahreza
# Processing Record 39 of Set 4 | hofn
# Processing Record 40 of Set 4 | preeceville
# Processing Record 41 of Set 4 | nanortalik
# Processing Record 42 of Set 4 | marsa matruh
# Processing Record 43 of Set 4 | tabas
# Processing Record 44 of Set 4 | dikson
# Processing Record 45 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 4 | gamboma
# Processing Record 47 of Set 4 | srednekolymsk
# Processing Record 48 of Set 4 | nikolskoye
# Processing Record 49 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 5 | kadykchan
# City not found. Skipping...
# Processing Record 2 of Set 5 | serenje
# Processing Record 3 of Set 5 | san patricio
# Processing Record 4 of Set 5 | quthing
# Processing Record 5 of Set 5 | upernavik
# Processing Record 6 of Set 5 | along
# Processing Record 7 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 5 | makakilo city
# Processing Record 9 of Set 5 | satara
# Processing Record 10 of Set 5 | nongan
# Processing Record 11 of Set 5 | loandjili
# Processing Record 12 of Set 5 | rayong
# Processing Record 13 of Set 5 | provideniya
# Processing Record 14 of Set 5 | itarema
# Processing Record 15 of Set 5 | kuito
# Processing Record 16 of Set 5 | beian
# Processing Record 17 of Set 5 | shenjiamen
# Processing Record 18 of Set 5 | moshenskoye
# Processing Record 19 of Set 5 | lavrentiya
# Processing Record 20 of Set 5 | langenburg
# Processing Record 21 of Set 5 | jacqueville
# Processing Record 22 of Set 5 | vaitape
# Processing Record 23 of Set 5 | kieta
# Processing Record 24 of Set 5 | mosquera
# Processing Record 25 of Set 5 | santiago del estero
# Processing Record 26 of Set 5 | san cristobal
# Processing Record 27 of Set 5 | berdigestyakh
# Processing Record 28 of Set 5 | vysokogornyy
# Processing Record 29 of Set 5 | moss point
# Processing Record 30 of Set 5 | brae
# Processing Record 31 of Set 5 | roald
# Processing Record 32 of Set 5 | novikovo
# Processing Record 33 of Set 5 | copiapo
# Processing Record 34 of Set 5 | port-cartier
# Processing Record 35 of Set 5 | pedernales
# Processing Record 36 of Set 5 | saint-philippe
# Processing Record 37 of Set 5 | aklavik
# Processing Record 38 of Set 5 | tommot
# Processing Record 39 of Set 5 | batagay
# Processing Record 40 of Set 5 | turukhansk
# Processing Record 41 of Set 5 | oranjemund
# Processing Record 42 of Set 5 | senneterre
# Processing Record 43 of Set 5 | aswan
# Processing Record 44 of Set 5 | victor harbor
# Processing Record 45 of Set 5 | ojinaga
# Processing Record 46 of Set 5 | birao
# Processing Record 47 of Set 5 | belmonte
# Processing Record 48 of Set 5 | clyde river
# Processing Record 49 of Set 5 | chapais
# Processing Record 50 of Set 5 | nabire
# Processing Record 1 of Set 6 | daru
# Processing Record 2 of Set 6 | nova russas
# Processing Record 3 of Set 6 | karasuk
# Processing Record 4 of Set 6 | north bend
# Processing Record 5 of Set 6 | buin
# Processing Record 6 of Set 6 | tucuman
# Processing Record 7 of Set 6 | san angelo
# Processing Record 8 of Set 6 | wanning
# Processing Record 9 of Set 6 | whitehorse
# Processing Record 10 of Set 6 | dauphin
# Processing Record 11 of Set 6 | trairi
# Processing Record 12 of Set 6 | kushmurun
# Processing Record 13 of Set 6 | pitimbu
# Processing Record 14 of Set 6 | yerbogachen
# Processing Record 15 of Set 6 | meulaboh
# Processing Record 16 of Set 6 | san ramon
# Processing Record 17 of Set 6 | te anau
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | cabadiangan
# Processing Record 20 of Set 6 | grindavik
# Processing Record 21 of Set 6 | gat
# Processing Record 22 of Set 6 | jurado
# Processing Record 23 of Set 6 | touros
# Processing Record 24 of Set 6 | warrnambool
# Processing Record 25 of Set 6 | sorland
# Processing Record 26 of Set 6 | inhambane
# Processing Record 27 of Set 6 | nishihara
# Processing Record 28 of Set 6 | hobyo
# Processing Record 29 of Set 6 | general pico
# Processing Record 30 of Set 6 | mutsamudu
# City not found. Skipping...
# Processing Record 31 of Set 6 | jamui
# Processing Record 32 of Set 6 | russell
# Processing Record 33 of Set 6 | orsta
# Processing Record 34 of Set 6 | seymchan
# Processing Record 35 of Set 6 | iqaluit
# Processing Record 36 of Set 6 | tramandai
# Processing Record 37 of Set 6 | hervey bay
# Processing Record 38 of Set 6 | timizart
# Processing Record 39 of Set 6 | beloha
# Processing Record 40 of Set 6 | uniao
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | portland
# Processing Record 43 of Set 6 | zemio
# Processing Record 44 of Set 6 | fort nelson
# Processing Record 45 of Set 6 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 46 of Set 6 | sayyan
# Processing Record 47 of Set 6 | horsham
# Processing Record 48 of Set 6 | rock sound
# Processing Record 49 of Set 6 | vila velha
# Processing Record 50 of Set 6 | dongkan
# Processing Record 1 of Set 7 | khandbari
# Processing Record 2 of Set 7 | merida
# Processing Record 3 of Set 7 | chengde
# Processing Record 4 of Set 7 | puerto escondido
# Processing Record 5 of Set 7 | matam
# Processing Record 6 of Set 7 | vianopolis
# Processing Record 7 of Set 7 | wazzan
# City not found. Skipping...
# Processing Record 8 of Set 7 | moose factory
# Processing Record 9 of Set 7 | bilibino
# Processing Record 10 of Set 7 | estelle
# Processing Record 11 of Set 7 | kahului
# Processing Record 12 of Set 7 | tuatapere
# Processing Record 13 of Set 7 | sao miguel do araguaia
# Processing Record 14 of Set 7 | los llanos de aridane
# Processing Record 15 of Set 7 | erzin
# Processing Record 16 of Set 7 | mount gambier
# Processing Record 17 of Set 7 | talnakh
# Processing Record 18 of Set 7 | tokur
# Processing Record 19 of Set 7 | chirongui
# Processing Record 20 of Set 7 | bambanglipuro
# Processing Record 21 of Set 7 | lazaro cardenas
# Processing Record 22 of Set 7 | salto
# Processing Record 23 of Set 7 | aranda de duero
# Processing Record 24 of Set 7 | port shepstone
# Processing Record 25 of Set 7 | fuyang
# Processing Record 26 of Set 7 | sistranda
# Processing Record 27 of Set 7 | mormugao
# Processing Record 28 of Set 7 | nuuk
# Processing Record 29 of Set 7 | nynashamn
# Processing Record 30 of Set 7 | pandan niog
# Processing Record 31 of Set 7 | machilipatnam
# Processing Record 32 of Set 7 | sarangani
# Processing Record 33 of Set 7 | vao
# Processing Record 34 of Set 7 | itumbiara
# Processing Record 35 of Set 7 | zhanatas
# City not found. Skipping...
# Processing Record 36 of Set 7 | magadan
# Processing Record 37 of Set 7 | tutoia
# Processing Record 38 of Set 7 | taoudenni
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | hihifo
# City not found. Skipping...
# Processing Record 41 of Set 7 | kansk
# Processing Record 42 of Set 7 | kavieng
# Processing Record 43 of Set 7 | kamenka
# Processing Record 44 of Set 7 | panalingaan
# Processing Record 45 of Set 7 | rajanpur
# Processing Record 46 of Set 7 | bell ville
# Processing Record 47 of Set 7 | hoshangabad
# Processing Record 48 of Set 7 | san francisco
# Processing Record 49 of Set 7 | shaunavon
# Processing Record 50 of Set 7 | peniche
# Processing Record 1 of Set 8 | maragogi
# Processing Record 2 of Set 8 | wawa
# Processing Record 3 of Set 8 | aguimes
# Processing Record 4 of Set 8 | nemuro
# Processing Record 5 of Set 8 | kuytun
# Processing Record 6 of Set 8 | foldes
# Processing Record 7 of Set 8 | burns lake
# Processing Record 8 of Set 8 | wufeng
# Processing Record 9 of Set 8 | coihaique
# Processing Record 10 of Set 8 | ode
# Processing Record 11 of Set 8 | kaniama
# Processing Record 12 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 8 | ivanava
# Processing Record 14 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 15 of Set 8 | mahibadhoo
# Processing Record 16 of Set 8 | fortuna
# Processing Record 17 of Set 8 | cap malheureux
# Processing Record 18 of Set 8 | provost
# Processing Record 19 of Set 8 | alice springs
# Processing Record 20 of Set 8 | ludwigslust
# Processing Record 21 of Set 8 | dingle
# Processing Record 22 of Set 8 | puerto del rosario
# Processing Record 23 of Set 8 | goderich
# Processing Record 24 of Set 8 | gazanjyk
# Processing Record 25 of Set 8 | norman wells
# Processing Record 26 of Set 8 | coquimbo
# Processing Record 27 of Set 8 | qui nhon
# Processing Record 28 of Set 8 | muros
# Processing Record 29 of Set 8 | birjand
# Processing Record 30 of Set 8 | qaanaaq
# Processing Record 31 of Set 8 | pisco
# Processing Record 32 of Set 8 | airai
# Processing Record 33 of Set 8 | palmer
# Processing Record 34 of Set 8 | gilazi
# City not found. Skipping...
# Processing Record 35 of Set 8 | majene
# Processing Record 36 of Set 8 | ust-maya
# Processing Record 37 of Set 8 | omboue
# Processing Record 38 of Set 8 | codrington
# Processing Record 39 of Set 8 | mayumba
# Processing Record 40 of Set 8 | srikakulam
# Processing Record 41 of Set 8 | bay city
# Processing Record 42 of Set 8 | rodrigues alves
# Processing Record 43 of Set 8 | luanda
# Processing Record 44 of Set 8 | mandalgovi
# Processing Record 45 of Set 8 | garden city
# Processing Record 46 of Set 8 | iranshahr
# Processing Record 47 of Set 8 | turan
# Processing Record 48 of Set 8 | ruidoso
# Processing Record 49 of Set 8 | saint-louis
# Processing Record 50 of Set 8 | yakeshi
# Processing Record 1 of Set 9 | minuri
# Processing Record 2 of Set 9 | abbeville
# Processing Record 3 of Set 9 | jequitinhonha
# Processing Record 4 of Set 9 | moyale
# Processing Record 5 of Set 9 | faanui
# Processing Record 6 of Set 9 | valencia
# Processing Record 7 of Set 9 | vostok
# Processing Record 8 of Set 9 | akonolinga
# Processing Record 9 of Set 9 | esperance
# Processing Record 10 of Set 9 | pervoavgustovskiy
# Processing Record 11 of Set 9 | yaan
# Processing Record 12 of Set 9 | zaranj
# Processing Record 13 of Set 9 | iwade
# Processing Record 14 of Set 9 | havoysund
# Processing Record 15 of Set 9 | galle
# Processing Record 16 of Set 9 | chernushka
# Processing Record 17 of Set 9 | honningsvag
# Processing Record 18 of Set 9 | srivardhan
# Processing Record 19 of Set 9 | kupang
# Processing Record 20 of Set 9 | vila franca do campo
# Processing Record 21 of Set 9 | biltine
# Processing Record 22 of Set 9 | vryheid
# Processing Record 23 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 24 of Set 9 | kloulklubed
# Processing Record 25 of Set 9 | pueblo
# Processing Record 26 of Set 9 | batticaloa
# Processing Record 27 of Set 9 | hay river
# Processing Record 28 of Set 9 | muli
# Processing Record 29 of Set 9 | albanel
# Processing Record 30 of Set 9 | wanaka
# Processing Record 31 of Set 9 | puerto carreno
# Processing Record 32 of Set 9 | banmo
# City not found. Skipping...
# Processing Record 33 of Set 9 | san isidro
# Processing Record 34 of Set 9 | shimoda
# Processing Record 35 of Set 9 | atasu
# Processing Record 36 of Set 9 | nguiu
# City not found. Skipping...
# Processing Record 37 of Set 9 | sovetskaya gavan
# Processing Record 38 of Set 9 | altamira
# Processing Record 39 of Set 9 | ust-omchug
# Processing Record 40 of Set 9 | pabrade
# Processing Record 41 of Set 9 | mucurapo
# Processing Record 42 of Set 9 | lakhdenpokhya
# Processing Record 43 of Set 9 | teahupoo
# Processing Record 44 of Set 9 | carmen
# Processing Record 45 of Set 9 | salalah
# Processing Record 46 of Set 9 | matou
# Processing Record 47 of Set 9 | cairns
# Processing Record 48 of Set 9 | matamoros
# Processing Record 49 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 9 | bowen
# Processing Record 1 of Set 10 | muzaffarpur
# Processing Record 2 of Set 10 | salta
# Processing Record 3 of Set 10 | mpika
# Processing Record 4 of Set 10 | kaiyuan
# Processing Record 5 of Set 10 | praia da vitoria
# Processing Record 6 of Set 10 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 10 | wilmington
# Processing Record 8 of Set 10 | jujuy
# City not found. Skipping...
# Processing Record 9 of Set 10 | atherton
# Processing Record 10 of Set 10 | kismayo
# Processing Record 11 of Set 10 | nome
# Processing Record 12 of Set 10 | saint-georges
# Processing Record 13 of Set 10 | lompoc
# Processing Record 14 of Set 10 | grand gaube
# Processing Record 15 of Set 10 | cotonou
# Processing Record 16 of Set 10 | fairbanks
# Processing Record 17 of Set 10 | whitley bay
# Processing Record 18 of Set 10 | nizwa
# Processing Record 19 of Set 10 | nizhneyansk
# City not found. Skipping...
# Processing Record 20 of Set 10 | kovdor
# Processing Record 21 of Set 10 | tuni
# Processing Record 22 of Set 10 | presov
# Processing Record 23 of Set 10 | rantepao
# Processing Record 24 of Set 10 | namatanai
# Processing Record 25 of Set 10 | minas
# Processing Record 26 of Set 10 | imbituba
# Processing Record 27 of Set 10 | kiruna
# Processing Record 28 of Set 10 | auki
# Processing Record 29 of Set 10 | pasni
# Processing Record 30 of Set 10 | port hawkesbury
# Processing Record 31 of Set 10 | atar
# Processing Record 32 of Set 10 | jablah
# Processing Record 33 of Set 10 | bonthe
# Processing Record 34 of Set 10 | chandur
# Processing Record 35 of Set 10 | cidreira
# Processing Record 36 of Set 10 | sharanga
# Processing Record 37 of Set 10 | linfen
# Processing Record 38 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 39 of Set 10 | senador jose porfirio
# Processing Record 40 of Set 10 | severo-kurilsk
# Processing Record 41 of Set 10 | noyabrsk
# Processing Record 42 of Set 10 | bodo
# Processing Record 43 of Set 10 | vaitupu
# City not found. Skipping...
# Processing Record 44 of Set 10 | roblin
# Processing Record 45 of Set 10 | scarborough
# Processing Record 46 of Set 10 | thunder bay
# Processing Record 47 of Set 10 | plettenberg bay
# Processing Record 48 of Set 10 | obanazawa
# Processing Record 49 of Set 10 | quesnel
# Processing Record 50 of Set 10 | escanaba
# Processing Record 1 of Set 11 | sheksna
# Processing Record 2 of Set 11 | husavik
# Processing Record 3 of Set 11 | asosa
# Processing Record 4 of Set 11 | sola
# Processing Record 5 of Set 11 | kurya
# Processing Record 6 of Set 11 | nantucket
# Processing Record 7 of Set 11 | yenagoa
# Processing Record 8 of Set 11 | vestmannaeyjar
# Processing Record 9 of Set 11 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 10 of Set 11 | amuntai
# Processing Record 11 of Set 11 | goulburn
# Processing Record 12 of Set 11 | udachnyy
# Processing Record 13 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 14 of Set 11 | bernau
# Processing Record 15 of Set 11 | college
# Processing Record 16 of Set 11 | morondava
# Processing Record 17 of Set 11 | pili
# Processing Record 18 of Set 11 | hualmay
# Processing Record 19 of Set 11 | sur
# Processing Record 20 of Set 11 | shakawe
# Processing Record 21 of Set 11 | kabo
# Processing Record 22 of Set 11 | nyurba
# Processing Record 23 of Set 11 | sri aman
# Processing Record 24 of Set 11 | banjar
# Processing Record 25 of Set 11 | sangolqui
# Processing Record 26 of Set 11 | san ignacio
# Processing Record 27 of Set 11 | matay
# Processing Record 28 of Set 11 | ondo
# Processing Record 29 of Set 11 | cockburn town
# Processing Record 30 of Set 11 | mackenzie
# Processing Record 31 of Set 11 | lagoa
# Processing Record 32 of Set 11 | san pedro
# Processing Record 33 of Set 11 | yingcheng
# Processing Record 34 of Set 11 | kununurra
# Processing Record 35 of Set 11 | tiznit
# Processing Record 36 of Set 11 | palana
# Processing Record 37 of Set 11 | kushima
# Processing Record 38 of Set 11 | mendota
# Processing Record 39 of Set 11 | manzil tamim
# City not found. Skipping...
# Processing Record 40 of Set 11 | flinders
# Processing Record 41 of Set 11 | samarai
# Processing Record 42 of Set 11 | masumbwe
# Processing Record 43 of Set 11 | beeskow
# Processing Record 44 of Set 11 | purpe
# Processing Record 45 of Set 11 | port blair
# Processing Record 46 of Set 11 | huarmey
# Processing Record 47 of Set 11 | maykain
# City not found. Skipping...
# Processing Record 48 of Set 11 | akdepe
# Processing Record 49 of Set 11 | buraydah
# Processing Record 50 of Set 11 | banikoara
# Processing Record 1 of Set 12 | azangaro
# Processing Record 2 of Set 12 | port augusta
# Processing Record 3 of Set 12 | eldikan
# City not found. Skipping...
# Processing Record 4 of Set 12 | port macquarie
# Processing Record 5 of Set 12 | bull savanna
# Processing Record 6 of Set 12 | nara
# Processing Record 7 of Set 12 | hamilton
# Processing Record 8 of Set 12 | kaeo
# Processing Record 9 of Set 12 | kasempa
# Processing Record 10 of Set 12 | okhotsk
# Processing Record 11 of Set 12 | lopatino
# Processing Record 12 of Set 12 | jamiltepec
# Processing Record 13 of Set 12 | port hardy
# Processing Record 14 of Set 12 | superior
# Processing Record 15 of Set 12 | san policarpo
# Processing Record 16 of Set 12 | nurota
# Processing Record 17 of Set 12 | porto belo
# Processing Record 18 of Set 12 | san carlos de bariloche
# Processing Record 19 of Set 12 | dunedin
# Processing Record 20 of Set 12 | terrace
# Processing Record 21 of Set 12 | malayal
# Processing Record 22 of Set 12 | manzanillo
# Processing Record 23 of Set 12 | cottonwood
# Processing Record 24 of Set 12 | carutapera
# Processing Record 25 of Set 12 | cristalina
# Processing Record 26 of Set 12 | ancud
# Processing Record 27 of Set 12 | artyk
# City not found. Skipping...
# Processing Record 28 of Set 12 | margate
# Processing Record 29 of Set 12 | rio grande
# Processing Record 30 of Set 12 | mut
# Processing Record 31 of Set 12 | vila
# Processing Record 32 of Set 12 | saint-joseph
# Processing Record 33 of Set 12 | ribeira brava
# Processing Record 34 of Set 12 | almaznyy
# Processing Record 35 of Set 12 | manggar
# Processing Record 36 of Set 12 | kenora
# Processing Record 37 of Set 12 | mount darwin
# Processing Record 38 of Set 12 | cherskiy
# Processing Record 39 of Set 12 | nanakuli
# Processing Record 40 of Set 12 | newport
# Processing Record 41 of Set 12 | gornji vakuf
# Processing Record 42 of Set 12 | daxian
# City not found. Skipping...
# Processing Record 43 of Set 12 | erice
# Processing Record 44 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 45 of Set 12 | okha
# Processing Record 46 of Set 12 | phan rang
# City not found. Skipping...
# Processing Record 47 of Set 12 | abaza
# Processing Record 48 of Set 12 | katangli
# Processing Record 49 of Set 12 | bethanien
# Processing Record 50 of Set 12 | ye
# City not found. Skipping...
# Processing Record 1 of Set 13 | muzhi
# Processing Record 2 of Set 13 | tura
# Processing Record 3 of Set 13 | waipawa
# Processing Record 4 of Set 13 | rio gallegos
# Processing Record 5 of Set 13 | mount isa
# Processing Record 6 of Set 13 | darnah
# Processing Record 7 of Set 13 | kasongo-lunda
# Processing Record 8 of Set 13 | tautira
# Processing Record 9 of Set 13 | natal
# Processing Record 10 of Set 13 | oudtshoorn
# Processing Record 11 of Set 13 | shingu
# Processing Record 12 of Set 13 | harboore
# Processing Record 13 of Set 13 | shirokiy
# Processing Record 14 of Set 13 | viksoyri
# City not found. Skipping...
# Processing Record 15 of Set 13 | susangerd
# Processing Record 16 of Set 13 | aketi
# Processing Record 17 of Set 13 | manokwari
# Processing Record 18 of Set 13 | klaksvik
# Processing Record 19 of Set 13 | ostrovnoy
# Processing Record 20 of Set 13 | nattam
# Processing Record 21 of Set 13 | abu kamal
# Processing Record 22 of Set 13 | bathsheba
# Processing Record 23 of Set 13 | poway
# Processing Record 24 of Set 13 | axim
# Processing Record 25 of Set 13 | ust-ilimsk
# Processing Record 26 of Set 13 | cilegon
# Processing Record 27 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 28 of Set 13 | ust-nera
# Processing Record 29 of Set 13 | celestun
# Processing Record 30 of Set 13 | kirkwood
# Processing Record 31 of Set 13 | lindi
# Processing Record 32 of Set 13 | springbok
# Processing Record 33 of Set 13 | haines junction
# Processing Record 34 of Set 13 | berlevag
# Processing Record 35 of Set 13 | kurchaloy
# Processing Record 36 of Set 13 | lethem
# Processing Record 37 of Set 13 | jumla
# Processing Record 38 of Set 13 | muhos
# Processing Record 39 of Set 13 | winnemucca
# Processing Record 40 of Set 13 | lorengau
# Processing Record 41 of Set 13 | karkaralinsk
# City not found. Skipping...
# Processing Record 42 of Set 13 | kontagora
# Processing Record 43 of Set 13 | arlit
# Processing Record 44 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 45 of Set 13 | weinan
# Processing Record 46 of Set 13 | askarovo
# Processing Record 47 of Set 13 | tomatlan
# Processing Record 48 of Set 13 | acapulco
# Processing Record 49 of Set 13 | nenton
# Processing Record 50 of Set 13 | macaboboni
# City not found. Skipping...
# Processing Record 1 of Set 14 | petropavlovka
# Processing Record 2 of Set 14 | tiarei
# Processing Record 3 of Set 14 | maturin
# Processing Record 4 of Set 14 | hunza
# City not found. Skipping...
# Processing Record 5 of Set 14 | uribia
# Processing Record 6 of Set 14 | ternate
# Processing Record 7 of Set 14 | lima
# Processing Record 8 of Set 14 | viligili
# City not found. Skipping...
# Processing Record 9 of Set 14 | mogadishu
# Processing Record 10 of Set 14 | terrak
# Processing Record 11 of Set 14 | lincoln
# Processing Record 12 of Set 14 | ulladulla
# Processing Record 13 of Set 14 | praia
# Processing Record 14 of Set 14 | bayji
# Processing Record 15 of Set 14 | ekibastuz
# Processing Record 16 of Set 14 | shar
# Processing Record 17 of Set 14 | san jose
# Processing Record 18 of Set 14 | la rochelle
# Processing Record 19 of Set 14 | otradnoye
# Processing Record 20 of Set 14 | lichinga
# Processing Record 21 of Set 14 | svetlyy
# Processing Record 22 of Set 14 | fairview
# Processing Record 23 of Set 14 | doctor juan manuel frutos
# Processing Record 24 of Set 14 | neuquen
# Processing Record 25 of Set 14 | stornoway
# Processing Record 26 of Set 14 | aitape
# Processing Record 27 of Set 14 | ambon
# Processing Record 28 of Set 14 | kibre mengist
# Processing Record 29 of Set 14 | kargasok
# Processing Record 30 of Set 14 | araouane
# Processing Record 31 of Set 14 | shihezi
# Processing Record 32 of Set 14 | latur
# Processing Record 33 of Set 14 | betsiamites
# Processing Record 34 of Set 14 | dzhebariki-khaya
# Processing Record 35 of Set 14 | poum
# Processing Record 36 of Set 14 | pathein
# Processing Record 37 of Set 14 | forest grove
# Processing Record 38 of Set 14 | spassk
# Processing Record 39 of Set 14 | alihe
# Processing Record 40 of Set 14 | smolenskoye
# Processing Record 41 of Set 14 | riyaq
# City not found. Skipping...
# Processing Record 42 of Set 14 | jalu
# Processing Record 43 of Set 14 | leshukonskoye
# Processing Record 44 of Set 14 | valday
# Processing Record 45 of Set 14 | bubaque
# Processing Record 46 of Set 14 | fukue
# Processing Record 47 of Set 14 | makhinjauri
# Processing Record 48 of Set 14 | ustye
# Processing Record 49 of Set 14 | oistins
# Processing Record 50 of Set 14 | poya
# Processing Record 1 of Set 15 | quatre cocos
# Processing Record 2 of Set 15 | kuching
# Processing Record 3 of Set 15 | vanimo
# Processing Record 4 of Set 15 | faya
# Processing Record 5 of Set 15 | teluk nibung
# Processing Record 6 of Set 15 | tessalit
# Processing Record 7 of Set 15 | bulgan
# Processing Record 8 of Set 15 | bedesa
# Processing Record 9 of Set 15 | trinidad
# Processing Record 10 of Set 15 | pueblo nuevo
# Processing Record 11 of Set 15 | westport
# Processing Record 12 of Set 15 | krasnoarmeysk
# Processing Record 13 of Set 15 | weligama
# Processing Record 14 of Set 15 | gorin
# Processing Record 15 of Set 15 | plouzane
# Processing Record 16 of Set 15 | ugoofaaru
# Processing Record 17 of Set 15 | maceio
# Processing Record 18 of Set 15 | myrtle beach
# Processing Record 19 of Set 15 | barawe
# City not found. Skipping...
# Processing Record 20 of Set 15 | anadyr
# Processing Record 21 of Set 15 | krutikha
# Processing Record 22 of Set 15 | alofi
# Processing Record 23 of Set 15 | grand baie
# Processing Record 24 of Set 15 | mata de sao joao
# Processing Record 25 of Set 15 | coahuayana
# Processing Record 26 of Set 15 | northfield
# Processing Record 27 of Set 15 | tazovskiy
# Processing Record 28 of Set 15 | ban dung
# Processing Record 29 of Set 15 | imeni poliny osipenko
# Processing Record 30 of Set 15 | mantua
# Processing Record 31 of Set 15 | raymond
# Processing Record 32 of Set 15 | mosetse
# Processing Record 33 of Set 15 | xai-xai
# Processing Record 34 of Set 15 | havre-saint-pierre
# Processing Record 35 of Set 15 | fermo
# Processing Record 36 of Set 15 | zhicheng
# Processing Record 37 of Set 15 | ayan
# Processing Record 38 of Set 15 | rabaul
# Processing Record 39 of Set 15 | seminole
# Processing Record 40 of Set 15 | discovery bay
# Processing Record 41 of Set 15 | guiren
# Processing Record 42 of Set 15 | baruun-urt
# Processing Record 43 of Set 15 | petropavlovsk-kamchatskiy
# Processing Record 44 of Set 15 | rawson
# Processing Record 45 of Set 15 | tumannyy
# City not found. Skipping...
# Processing Record 46 of Set 15 | skovorodino
# Processing Record 47 of Set 15 | keetmanshoop
# Processing Record 48 of Set 15 | pachino
# Processing Record 49 of Set 15 | jimma
# Processing Record 50 of Set 15 | tucurui
# Processing Record 1 of Set 16 | bulawayo
# Processing Record 2 of Set 16 | guerrero negro
# Processing Record 3 of Set 16 | paiho
# City not found. Skipping...
# Processing Record 4 of Set 16 | santa vitoria do palmar
# Processing Record 5 of Set 16 | senj
# Processing Record 6 of Set 16 | aksay
# Processing Record 7 of Set 16 | vitim
# Processing Record 8 of Set 16 | jieshi
# Processing Record 9 of Set 16 | salisbury
# Processing Record 10 of Set 16 | leninsk
# Processing Record 11 of Set 16 | athabasca
# Processing Record 12 of Set 16 | faizabad
# Processing Record 13 of Set 16 | labuhan
# Processing Record 14 of Set 16 | marawi
# Processing Record 15 of Set 16 | polovinnoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
new_order = ['City','Country', 'Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
weatherpy_db = weatherpy_db[new_order]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/jz/tx6pn2mx433_2vnzgjk45jn00000gn/T/ipykernel_1509/3173912039.py in <module>
#       1 new_order = ['City','Country', 'Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
# ----> 2 weatherpy_db = weatherpy_db[new_order]
#       3
#
# NameError: name 'weatherpy_db' is not defined

# %%
weatherpy_db.head(10)

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
weatherpy_db.to_csv(output_data_file, index_label="City_ID")
